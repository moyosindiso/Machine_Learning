# %% [markdown]
# <a href="https://colab.research.google.com/github/moyosindiso/Machine_Learning/blob/main/YoloV8_Birds_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bird Classification Using YOLOv8 (Vulture, Stork, Hawk, Eagle)

# %% [markdown]
# *Installing ultralytics*

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.0/755.0 kB 1.9 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %% [markdown]
# *Google Drive direct download of big files*

# %%
# !pip install gdown

# %% [markdown]
# *Now downloading Files from Google drive using the shared link of the zipped file*

# %%
# !gdown 1Ey-CeheO_hxxL-rGYskr2nmnxl-WnqsU
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Ey-CeheO_hxxL-rGYskr2nmnxl-WnqsU
# From (redirected): https://drive.google.com/uc?id=1Ey-CeheO_hxxL-rGYskr2nmnxl-WnqsU&confirm=t&uuid=8f896716-ba3c-4879-b54e-ca8d8a283fde
# To: /content/BirdsDatasetYolo8.zip
# 100% 574M/574M [00:05<00:00, 97.5MB/s]

# %% [markdown]
# *Now Unzipping the file*

# %%
# !unzip BirdsDatasetYolo8.zip
# Out:
# Archive:  BirdsDatasetYolo8.zip
#    creating: BirdsDatasetYolo8/test/
#    creating: BirdsDatasetYolo8/test/eagle/
#   inflating: BirdsDatasetYolo8/test/eagle/eagle103.jpg
#   inflating: BirdsDatasetYolo8/test/eagle/eagle105.jpg
#   inflating: BirdsDatasetYolo8/test/eagle/eagle12.jpg
#   inflating: BirdsDatasetYolo8/test/eagle/eagle125.jpg
#   inflating: BirdsDatasetYolo8/test/eagle/eagle13.jpg
#   inflating: BirdsDatasetYolo8/test/eagle/eagle140.jpg
#   inflating: BirdsDatasetYolo8/test/eagle/eagle145.jpg
#   inflating: BirdsDatasetYolo8/test/eagle/eagle151.jpg
#   inflating: BirdsDatasetYolo8/test/eagle/eagle152.jpg
#   inflating: BirdsDatasetYolo8/test/eagle/eagle158.jpeg
#   inflating: BirdsDatasetYolo8/test/eagle/eagle160.jpeg
#   inflating: BirdsDatasetYolo8/test/eagle/eagle166.jpeg
#   inflating: BirdsDatasetYolo8/test/eagle/eagle173.jpeg
#   inflating: BirdsDatasetYolo8/test/eagle/eagle179.jpeg
#   inflating: BirdsDatasetYolo8/test/eagle/eagle19.jpg
# ...

# %% [markdown]
# *Training*

# %%
# !yolo classify train data=BirdsDatasetYolo8 model=yolov8l-cls.pt epochs=5 imgsz=128 dropout=0.5 label_smoothing=0.1
# Out:
# ...
# 100% 71.7M/71.7M [00:00<00:00, 204MB/s]
# Ultralytics YOLOv8.2.6 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %% [markdown]
# *Prediction model*

# %%
# !yolo classify predict model=runs/classify/train/weights/best.pt source=images/vulture_Validation1.jpg
# Out:
# Ultralytics YOLOv8.2.6 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8l-cls summary (fused): 133 layers, 36190981 parameters, 0 gradients, 98.7 GFLOPs
#
# image 1/1 /content/images/vulture_Validation1.jpg: 128x128 vulture 1.00, storks 0.00, hawk 0.00, eagle 0.00, falcon 0.00, 126.8ms
# Speed: 25.8ms preprocess, 126.8ms inference, 0.1ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs/classify/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
